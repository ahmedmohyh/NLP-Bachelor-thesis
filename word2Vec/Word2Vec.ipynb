# %% [markdown]
# ## Importing all necessary libararies

# %%
from gensim.models import Word2Vec
from Utility.ThesisUtility import vectorize, mbkmeans_clusters,writeClustersToExcel,getSentenceUsingStructringWords,printPairsEvaluation,printPurity,getSentcesAndTokens

# %% [markdown]
# ### Constants

# %%
dataFilePath = "../Dataset/Essays_all/TelevisonMergedT1+T2"
evaluationFilePath = "../CSV Files/Clusters Evaluation results/Gold vs Clusters - Word2Vec.csv"
k = 19
modelFileName = "Word2VecSentences.txt"
clusterExcelSheetName = "clusteredArgument- Word2Vec - "

# %% [markdown]
# ### Reading the input(Essays) as text files and parsing it into sentences and tokens

# %%
sentences, tokensSentenceslist = getSentcesAndTokens(dataFilePath,True)

# %% [markdown]
# ### Generating the Word2Vec Model

# %%
model = Word2Vec(window=10, min_count=2,workers=6,vector_size=100,seed=42,sg=0)
model.build_vocab(tokensSentenceslist, progress_per=1000)
model.train(tokensSentenceslist, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (1313536, 1737390)

# %% [markdown]
# ### Vectorizing each sentence using the avg of the Word embidings of each word

# %%
vectorized_docs = vectorize(tokensSentenceslist, model=model, strategy="average")

# %% [markdown]
# ### Applying the Kmeans algorithm

# %%
clustering, cluster_labels = mbkmeans_clusters(X=vectorized_docs, k=19, print_silhouette_values=True)

writeClustersToExcel(clusterExcelSheetName,cluster_labels,k,sentences,vectorized_docs,clustering)
# Out:
# For n_clusters = 19
# Silhouette coefficient: 0.11
# Inertia:82968.08010841276
# Silhouette values:
#     Cluster 12: Size:171 | Avg:0.90 | Min:0.03 | Max: 0.94
#     Cluster 9: Size:492 | Avg:0.60 | Min:0.07 | Max: 0.67
#     Cluster 15: Size:3114 | Avg:0.16 | Min:-0.04 | Max: 0.40
#     Cluster 3: Size:1170 | Avg:0.16 | Min:-0.10 | Max: 0.41
#     Cluster 7: Size:3240 | Avg:0.14 | Min:0.01 | Max: 0.33
#     Cluster 8: Size:2490 | Avg:0.12 | Min:-0.14 | Max: 0.34
#     Cluster 5: Size:2604 | Avg:0.11 | Min:-0.08 | Max: 0.34
#     Cluster 2: Size:1217 | Avg:0.11 | Min:-0.08 | Max: 0.33
#     Cluster 14: Size:3362 | Avg:0.10 | Min:-0.10 | Max: 0.33
#     Cluster 16: Size:1533 | Avg:0.10 | Min:-0.10 | Max: 0.35
#     Cluster 0: Size:3907 | Avg:0.09 | Min:-0.07 | Max: 0.31
#     Cluster 6: Size:2963 | Avg:0.09 | Min:-0.08 | Max: 0.28
#     Cluster 10: Size:1261 | Avg:0.08 | Min:-0.16 | Max: 0.36
#     Cluster 13: Size:1913 | Avg:0.08 | Min:-0.08 | Max: 0.29
#     Cluster 4: Size:1835 | Avg:0.07 | Min:-0.25 | Max: 0.30
#     Cluster 1: Size:1673 | Avg:0.06 | Min:-0.14 | Max: 0.29
#     Cluster 11: Size:1432 | Avg:0.06 | Min:-0.16 | Max: 0.31
#     Cluster 18: Size:2946 | Avg:0.05 | Min:-0.10 | Max: 0.24
#     Cluster 17: Size:1392 | Avg:0.03 | Min:-0.10 | Max: 0.24
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:219: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ClsuteringSentencesCount = df_ClsuteringSentencesCount.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:219: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ClsuteringSentencesCount = df_ClsuteringSentencesCount.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:219: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ClsuteringSentencesCount = df_ClsuteringSentencesCount.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:219: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ClsuteringSentencesCount = df_ClsuteringSentencesCount.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:219: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ClsuteringSentencesCount = df_ClsuteringSentencesCount.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:219: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ClsuteringSentencesCount = df_ClsuteringSentencesCount.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:219: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ClsuteringSentencesCount = df_ClsuteringSentencesCount.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:219: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ClsuteringSentencesCount = df_ClsuteringSentencesCount.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:219: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ClsuteringSentencesCount = df_ClsuteringSentencesCount.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# ...
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:219: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ClsuteringSentencesCount = df_ClsuteringSentencesCount.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:219: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ClsuteringSentencesCount = df_ClsuteringSentencesCount.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({
# D:\USERS-Load\PycharmProjects\pythonProject\Utility\ThesisUtility.py:231: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mostRepresentative = df_mostRepresentative.append({

# %% [markdown]
# ### Clusters Evaluation

# %%
#Pairs evaluation metric
printPairsEvaluation(evaluationFilePath,"csv")

#Purity evaluation metric
printPurity(evaluationFilePath,"csv")
